# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Run generate_splits.py to convert the .mat dataset file to a dataframe and generate the 4 splits.
# %cd /content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp/data
# %run -i 'generate_splits.py'
# Out:
# /content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp/data
# Number of unique YouTube videos: 580
# Number of annotations: 1400

# %%
# Run train.py
# %cd /content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp/human_pose_model
# %run -i 'train.py'
# Out:
# /content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp
# Downloading: "https://www.dropbox.com/s/47tyzpofuuyyv1b/mobilenetv2_1.0-f2a8633.pth.tar?dl=1" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-f2a8633.pth.tar
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 30.9MB/s]
# Iteration: 0	Loss: 2.2176 (2.2176)
# Iteration: 1	Loss: 0.7151 (1.4663)
# Iteration: 2	Loss: 0.6236 (1.1854)
# Iteration: 3	Loss: 0.5071 (1.0158)
# Iteration: 4	Loss: 0.8437 (0.9814)
# Iteration: 5	Loss: 0.8234 (0.9551)
# Iteration: 6	Loss: 0.8683 (0.9427)
# Iteration: 7	Loss: 0.7469 (0.9182)
# Iteration: 8	Loss: 0.9153 (0.9179)
# Iteration: 9	Loss: 0.6617 (0.8923)
# Iteration: 10	Loss: 0.7294 (0.8775)
# Iteration: 11	Loss: 0.6970 (0.8624)
# Iteration: 12	Loss: 0.5714 (0.8400)
# Iteration: 13	Loss: 0.5535 (0.8196)
# Iteration: 14	Loss: 0.5314 (0.8003)
# Iteration: 15	Loss: 0.6471 (0.7908)
# Iteration: 16	Loss: 0.6062 (0.7799)
# Iteration: 17	Loss: 0.5744 (0.7685)
# Iteration: 18	Loss: 0.6337 (0.7614)
# ...

# %%
# Run evaluation
# %cd /content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp/human_pose_model
# %run -i 'eval.py'
# Out:
# /content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp
# Downloading: "https://www.dropbox.com/s/47tyzpofuuyyv1b/mobilenetv2_1.0-f2a8633.pth.tar?dl=1" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-f2a8633.pth.tar
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 66.1MB/s]
# Average PCE: 0.6953571428571429
#   sex    N   address    toe_up  mid_backswing       top  mid_downswing  \
# 0   f  159  0.163522  0.773585       0.823899  0.603774       0.981132
# 1   m  191  0.219895  0.832461       0.874346  0.633508       0.973822
#
#      impact  mid_follow_through    finish
# 0  0.968553            0.962264  0.138365
# 1  0.973822            0.984293  0.193717
#       club    N   address    toe_up  mid_backswing       top  mid_downswing  \
# 0   driver  235  0.204255  0.800000       0.859574  0.604255       0.978723
# 1  fairway   39  0.153846  0.794872       0.820513  0.641026       0.974359
# 2   hybrid   17  0.176471  0.882353       0.705882  0.588235       0.882353
# ...

# %%
# test image
# %cd /content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp/human_pose_model
# %run -i 'test_video.py' -p '/content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp/data/videos_160/191.mp4' -vp '/content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp/data/videos_160_human_pose/191.npy'
# Out:
# /content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp/human_pose_model
# Preparing video: /content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp/data/videos_160/191.mp4
# Using device: cuda
# Loaded model weights
# Testing...
# Predicted event frames: [ 64  75  80  86  90  93  95 111]
# Condifence: [0.306, 0.974, 0.974, 0.687, 0.99, 0.984, 0.995, 0.914]
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7F8E74AADE80>
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7F8E73C32490>
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7F8F49F62DC0>
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7F8E73C32490>
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7F8F49F62DC0>
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7F8E73C32490>
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7F8F49F62DC0>
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7F8E73C32490>
