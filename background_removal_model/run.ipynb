# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Run generate_splits.py to convert the .mat dataset file to a dataframe and generate the 4 splits.
# %cd /content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp/data
# %run -i 'generate_splits.py'
# Out:
# /content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp/data
# Number of unique YouTube videos: 580
# Number of annotations: 1400

# %% [markdown]
# * I have provided the preprocessed video clips for a frame size of 160x160 (download
# [here](https://drive.google.com/drive/folders/19o_le3SR7dFDCng86-IRvWwaB6PZ_kgd?usp=share_link)).
# Place 'videos_160_segmented' in the [data](./data/) directory.
# If you wish to use a different input configuration you must download the YouTube videos (URLs provided in
# dataset) and preprocess the videos yourself. I have provided [preprocess_videos.py](./data/preprocess_videos.py) to
# help with that.

# %%
# Run train.py
# %cd /content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp/background_removal_model
# %run -i 'train.py'
# Out:
# /content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp/background_removal_model
# Downloading: "https://www.dropbox.com/s/47tyzpofuuyyv1b/mobilenetv2_1.0-f2a8633.pth.tar?dl=1" to /root/.cache/torch/hub/checkpoints/mobilenetv2_1.0-f2a8633.pth.tar
# 100%|██████████| 13.5M/13.5M [00:01<00:00, 13.5MB/s]
# Iteration: 0	Loss: 2.1592 (2.1592)
# Iteration: 1	Loss: 0.7837 (1.4714)
# Iteration: 2	Loss: 0.4491 (1.1307)
# Iteration: 3	Loss: 0.7828 (1.0437)
# Iteration: 4	Loss: 0.8770 (1.0104)
# Iteration: 5	Loss: 0.8684 (0.9867)
# Iteration: 6	Loss: 0.5245 (0.9207)
# Iteration: 7	Loss: 0.7703 (0.9019)
# Iteration: 8	Loss: 0.7696 (0.8872)
# Iteration: 9	Loss: 0.6468 (0.8631)
# Iteration: 10	Loss: 0.6940 (0.8478)
# Iteration: 11	Loss: 0.7173 (0.8369)
# Iteration: 12	Loss: 0.6021 (0.8188)
# Iteration: 13	Loss: 0.7128 (0.8113)
# Iteration: 14	Loss: 0.5933 (0.7967)
# Iteration: 15	Loss: 0.6756 (0.7891)
# Iteration: 16	Loss: 0.5914 (0.7775)
# Iteration: 17	Loss: 0.5779 (0.7664)
# ...

# %%
# Run evaluation
# %cd /content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp/background_removal_model
# %run -i 'eval.py'
# Out:
# /content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp/background_removal_model
# Average PCE: 0.69
#   sex    N   address    toe_up  mid_backswing       top  mid_downswing  \
# 0   f  159  0.157233  0.672956       0.842767  0.792453       0.987421
# 1   m  191  0.141361  0.780105       0.795812  0.664921       0.984293
#
#      impact  mid_follow_through    finish
# 0  0.974843            0.968553  0.220126
# 1  0.979058            0.937173  0.157068
#       club    N   address    toe_up  mid_backswing       top  mid_downswing  \
# 0   driver  235  0.165957  0.740426       0.829787  0.744681       0.995745
# 1  fairway   39  0.102564  0.692308       0.615385  0.538462       0.923077
# 2   hybrid   17  0.235294  0.529412       0.823529  0.764706       0.941176
# 3     iron   56  0.089286  0.767857       0.892857  0.732143       1.000000
# 4    wedge    3  0.000000  1.000000       1.000000  1.000000       1.000000
#
#      impact  mid_follow_through    finish
# ...

# %%
# test image
# %cd /content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp/background_removal_model
# %run -i 'test_video.py' -p '/content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp/data/videos_160_segmented/191.mp4'
# Out:
# /content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp/background_removal_model
# Preparing video: /content/drive/MyDrive/Github/joeklein-gaalevy-wemarti-fp/data/videos_160_segmented/191.mp4
# Using device: cuda
# Loaded model weights
# Testing...
# Predicted event frames: [ 64  75  80  86  90  93  95 111]
# Condifence: [0.862, 0.968, 0.974, 0.687, 0.972, 0.994, 0.9, 0.919]
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7F479CA149A0>
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7F479CA14C40>
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7F479CA14BB0>
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7F479CA14910>
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7F479CA14B80>
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7F479CA14A30>
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7F479CA14940>
# <PIL.Image.Image image mode=RGB size=160x160 at 0x7F479CA14AF0>
